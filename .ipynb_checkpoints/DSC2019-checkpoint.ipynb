# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_exchange = pd.read_csv("./data/st_data_exchange.tsv",sep='\t') # 환전고시환율

df_kr_index = pd.read_csv("./data/st_data_koreaIndex.tsv",sep='\t') # 국내지수

df_item_charge_full = pd.read_csv("./data/st_data_itemChargeFull.tsv",sep='\t') # 종목시세 및 정보

df_foreign_charge = pd.read_csv("./data/st_data_foreignCharge.tsv",sep='\t') #해외지수

df_oil_kr = pd.read_csv("./data/st_data_oilKorea.tsv",sep='\t') # 국내 유가

df_oil_foreign = pd.read_csv("./data/st_data_oilForeign.tsv",sep='\t') # 해외 유가

df_gold_kr = pd.read_csv("./data/st_data_goldKorea.tsv",sep='\t') # 국내 금 시세

df_gold_foreign = pd.read_csv("./data/st_data_goldForeign.tsv",sep='\t') # 해외 금 시세

df_goods_foreign = pd.read_csv("./data/st_data_goodsForeign.tsv",sep='\t') # 해외 원자제 시세
# Out:
# /home/lee-dong-hyun/anaconda3/envs/DSC2019/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # DSC 2019 데이터 분석 과제

# %% [markdown]
# ## 데이터 탐색

# %% [markdown]
# ### 1. 환전고시환율

# %%
df_exchange.itemname2.value_counts()
# Out:
# 싱가포르SGD         323
# 일본JPY (100엔)    323
# 방글라데시BDT        323
# 폴란드PLN          323
# 카자흐스탄KZT        323
# 뉴질랜드NZD         323
# 브루나이BND         323
# 영국GBP           323
# 캐나다CAD          323
# 이집트EGP          323
# 덴마크DKK          323
# 이스라엘ILS         323
# 헝가리HUF          323
# 필리핀PHP          323
# 요르단JOD          323
# 스위스CHF          323
# 태국THB           323
# 사우디아라비아SAR      323
# 대만TWD           323
# 멕시코MXN          323
# 인도네시아IDR 100    323
# 인도INR           323
# 쿠웨이트KWD         323
# 러시아RUB          323
# 스웨덴SEK          323
# 터키TRY           323
# 노르웨이NOK         323
# 말레이시아MYR        323
# 파키스탄PKR         323
# 브라질BRL          323
# 중국CNY           323
# 몽골MNT           323
# 홍콩HKD           323
# 남아프리카공화국ZAR     323
# 호주AUD           323
# 카타르QAR          323
# 바레인BHD          323
# 오만OMR           323
# 미국USD           323
# 체코CZK           323
# 아랍에미리트AED       323
# 유럽연합EUR         323
# 칠레CLP           322
# 베트남VND 100      322
# Name: itemname2, dtype: int64

# %%
df_exchange.head()
# Out:
#     itemcode itemname      date  sale_base_rate  change_val  cash_buying_val  \
# 0  FX_AEDKRW      AED  20150107          299.34        0.13           311.31
# 1  FX_AEDKRW      AED  20150113          294.90       -0.36           306.69
# 2  FX_AEDKRW      AED  20150116          293.35       -0.38           305.08
# 3  FX_AEDKRW      AED  20150119          293.65        0.30           305.39
# 4  FX_AEDKRW      AED  20150122          295.31        0.19           307.12
#
#    cash_selling_val  send_money_val  receive_money_val  \
# 0            275.40          302.33             296.35
# 1            271.31          297.84             291.96
# 2            269.89          296.28             290.42
# 3            270.16          296.58             290.72
# 4            271.69          298.26             292.36
#
#    traveler_check_buying_val  foreign_check_selling_val  itemname2
# 0                        NaN                     296.16  아랍에미리트AED
# ...

# %%
len(df_exchange.itemname2.value_counts())
# Out:
# 44

# %%
df_exchange.groupby(df_exchange['itemname2']).count()
# Out:
#               itemcode  itemname  date  sale_base_rate  change_val  \
# itemname2
# 남아프리카공화국ZAR        323       323   323             323         320
# 노르웨이NOK            323       323   323             323         320
# 뉴질랜드NZD            323       323   323             323         322
# 대만TWD              323       323   323             323         313
# 덴마크DKK             323       323   323             323         323
# 러시아RUB             323       323   323             323         306
# 말레이시아MYR           323       323   323             323         321
# 멕시코MXN             323       323   323             323         322
# 몽골MNT              323       323   323             323          68
# 미국USD              323       323   323             323         311
# 바레인BHD             323       323   323             323         317
# 방글라데시BDT           323       323   323             323         305
# 베트남VND 100         322       322   322             322         269
# ...

# %%
df_exchange.loc[df_exchange.itemname2 == '대만TWD'].change_val
# Out:
# 12919    0.03
# 12920    0.01
# 12921    0.08
# 12922    0.09
# 12923    0.13
# 12924    0.12
# 12925   -0.04
# 12926    0.06
# 12927    0.07
# 12928    0.23
# 12929    0.14
# 12930    0.01
# 12931    0.11
# 12932   -0.07
# 12933   -0.02
# 12934   -0.07
# 12935    0.18
# 12936   -0.26
# 12937    0.13
# 12938   -0.12
# 12939    0.02
# 12940    0.01
# 12941    0.21
# 12942   -0.15
# 12943   -0.06
# 12944    0.01
# 12945    0.09
# 12946    0.16
# 12947   -0.07
# 12948   -0.01
#          ...
# 13212   -0.03
# 13213   -0.05
# 13214   -0.13
# 13215   -0.09
# 13216    0.20
# 13217     NaN
# 13218   -0.06
# 13219    0.21
# 13220   -0.03
# 13221   -0.02
# 13222    0.11
# 13223   -0.08
# 13224   -0.24
# 13225     NaN
# 13226   -0.05
# 13227    0.12
# 13228    0.06
# 13229   -0.01
# 13230    0.30
# 13231    0.15
# 13232     NaN
# 13233    0.09
# 13234    0.02
# 13235    0.01
# 13236    0.07
# 13237    0.14
# 13238    0.26
# 13239   -0.03
# 13240   -0.06
# 13241   -0.02
# ...

# %% [markdown]
# ___

# %% [markdown]
# ### 3. 종목 시세 및 정보

# %%
df_item_charge_full.itemname.value_counts()
# Out:
# 한진칼           323
# 서울식품우         323
# 삼본전자          323
# 이구산업          323
# 젬백스           323
# 휠라코리아         323
# 웰크론강원         323
# 한라홀딩스         323
# 유유제약          323
# 현대상사          323
# 삼지전자          323
# 동원F&B         323
# 진흥기업우B        323
# 와이오엠          323
# 화일약품          323
# 무림SP          323
# 이화공영          323
# 한국정보인증        323
# 에스에너지         323
# 엠씨넥스          323
# 화성밸브          323
# 한국토지신탁        323
# 인선이엔티         323
# 한탑            323
# 알티캐스트         323
# 데이터스트림즈       323
# 풀무원           323
# SKC코오롱PI      323
# W홀딩컴퍼니        323
# 푸른기술          323
#              ...
# 비엔에프코퍼레이션       7
# 하나머스트제6호스팩      7
# 엠아이텍            7
# 에코캡             6
# 교보8호스팩          6
# SK4호스팩          5
# 이노메트리           5
# 골든브릿지이안5호       5
# 대유에이피           5
# 머큐리             4
# 뉴트리             4
# 전진바이오팜          4
# 위지윅스튜디오         2
# 미래에셋대우스팩2호      2
# 대신밸런스제6호스팩      2
# 에이비엘바이오         2
# 삼성머스트스팩3호       2
# 테크엔             2
# 신영스팩4호          2
# ...

# %%
df_item_charge_full.itemname.value_counts()
# Out:
# 한진칼           323
# 서울식품우         323
# 삼본전자          323
# 이구산업          323
# 젬백스           323
# 휠라코리아         323
# 웰크론강원         323
# 한라홀딩스         323
# 유유제약          323
# 현대상사          323
# 삼지전자          323
# 동원F&B         323
# 진흥기업우B        323
# 와이오엠          323
# 화일약품          323
# 무림SP          323
# 이화공영          323
# 한국정보인증        323
# 에스에너지         323
# 엠씨넥스          323
# 화성밸브          323
# 한국토지신탁        323
# 인선이엔티         323
# 한탑            323
# 알티캐스트         323
# 데이터스트림즈       323
# 풀무원           323
# SKC코오롱PI      323
# W홀딩컴퍼니        323
# 푸른기술          323
#              ...
# 비엔에프코퍼레이션       7
# 하나머스트제6호스팩      7
# 엠아이텍            7
# 에코캡             6
# 교보8호스팩          6
# SK4호스팩          5
# 이노메트리           5
# 골든브릿지이안5호       5
# 대유에이피           5
# 머큐리             4
# 뉴트리             4
# 전진바이오팜          4
# 위지윅스튜디오         2
# 미래에셋대우스팩2호      2
# 대신밸런스제6호스팩      2
# 에이비엘바이오         2
# 삼성머스트스팩3호       2
# 테크엔             2
# 신영스팩4호          2
# ...

# %%
df_item_charge_full.loc[df_item_charge_full.itemcode == '000080'].operating_profit
# Out:
# 1938    904.0
# 1939    904.0
# 1940    904.0
# 1941    904.0
# 1942    904.0
# 1943    904.0
# 1944    904.0
# 1945    904.0
# 1946    904.0
# 1947    904.0
# 1948    904.0
# 1949    904.0
# 1950    904.0
# 1951    904.0
# 1952    904.0
# 1953    904.0
# 1954    904.0
# 1955    904.0
# 1956    904.0
# 1957    904.0
# 1958    904.0
# 1959    904.0
# 1960    904.0
# 1961    904.0
# 1962    904.0
# 1963    904.0
# 1964    904.0
# 1965    904.0
# 1966    904.0
# 1967    904.0
#         ...
# 2231    904.0
# 2232    904.0
# 2233    904.0
# 2234    904.0
# 2235    904.0
# 2236    904.0
# 2237    904.0
# 2238    904.0
# 2239    904.0
# 2240    904.0
# 2241    904.0
# 2242    904.0
# 2243    904.0
# 2244    904.0
# 2245    904.0
# 2246    904.0
# 2247    904.0
# 2248    904.0
# 2249    904.0
# 2250    904.0
# 2251    904.0
# 2252    904.0
# 2253    904.0
# 2254    904.0
# 2255    904.0
# 2256    904.0
# 2257    904.0
# 2258    904.0
# 2259    904.0
# 2260    904.0
# ...

# %%
df_item_charge_full.loc[df_item_charge_full.itemname == 'NAVER']
# Out:
#        itemcode itemname market      date  close_val  change_val  change_rate  \
# 272066   035420    NAVER  KOSPI  20150107   732000.0    -11000.0        -1.50
# 272067   035420    NAVER  KOSPI  20150113   740000.0    -10000.0        -1.35
# 272068   035420    NAVER  KOSPI  20150116   777000.0         NaN          NaN
# 272069   035420    NAVER  KOSPI  20150119   776000.0     -1000.0        -0.13
# 272070   035420    NAVER  KOSPI  20150122   765000.0    -15000.0        -1.96
# 272071   035420    NAVER  KOSPI  20150128   777000.0     13000.0         1.67
# 272072   035420    NAVER  KOSPI  20150203   712000.0      1000.0         0.14
# 272073   035420    NAVER  KOSPI  20150206   715000.0      3000.0         0.42
# 272074   035420    NAVER  KOSPI  20150209   681000.0    -34000.0        -4.99
# 272075   035420    NAVER  KOSPI  20150212   680000.0      7000.0         1.03
# 272076   035420    NAVER  KOSPI  20150224   637000.0     -2000.0        -0.31
# ...

# %%
len(df_item_charge_full)
# Out:
# 671018

# %%
len(df_item_charge_full.itemname.value_counts())
# Out:
# 2334

# %%
(df_item_charge_full.itemname.value_counts() < 323).value_counts()
# Out:
# False    1838
# True      496
# Name: itemname, dtype: int64

# %% [markdown]
# **총 2334개의 회사에 대하여 671018개의 데이터가 있고, 323개의 데이터가 없는 회사의 수는 496 이다.**

# %% [markdown]
# ___

# %% [markdown]
# ### 3. 유가 정보

# %%
len(df_oil_kr)
# Out:
# 487

# %%
df_oil_kr.itemname.value_counts()
# Out:
# 휘발유    487
# Name: itemname, dtype: int64

# %%
df_oil_foreign.itemcode.value_counts()
# Out:
# IPE@EB    333
# NYM@CL    333
# NYM@DC    331
# Name: itemcode, dtype: int64

# %% [markdown]
# IPE: 런던 국제 석유 거래소
# NYM: 뉴욕 상품 거래소
# CL: 원유 (Crude Oil,Light Sweet)
# DC

# %%
df_goods_foreign.itemname.value_counts()
# Out:
# 난방유       333
# 천연가스      333
# 설탕        331
# 쌀         330
# 소맥        330
# 옥수수       327
# 대두박       326
# 납         326
# 대두        326
# 대두유       326
# 주석        326
# 니켈        326
# 아연        326
# 알루미늄합금    326
# 구리        326
# Name: itemname, dtype: int64

# %%
df_kr_index
# Out:
#     itemcode      date  close_val  change_val  change_rate  acc_quant  \
# 0     KOSDAQ  20150107      56132       242.0         0.43     488995
# 1     KOSDAQ  20150113      57100      -376.0        -0.65     544245
# 2     KOSDAQ  20150116      57741      -398.0        -0.68     422973
# 3     KOSDAQ  20150119      57794        53.0         0.09     434141
# 4     KOSDAQ  20150122      57842      -592.0        -1.01     639503
# 5     KOSDAQ  20150128      59439       655.0         1.11     464531
# 6     KOSDAQ  20150203      59331       304.0         0.52     496838
# 7     KOSDAQ  20150206      60413       332.0         0.55     509773
# 8     KOSDAQ  20150209      59375     -1038.0        -1.72     512818
# 9     KOSDAQ  20150212      60224        83.0         0.14     510069
# 10    KOSDAQ  20150224      62131       579.0         0.94     467941
# 11    KOSDAQ  20150227      62456       748.0         1.21     498231
# ...

# %%
df_item_charge_full.head()
# Out:
#   itemcode itemname market      date  close_val  change_val  change_rate  \
# 0   000020     동화약품  KOSPI  20150107     5540.0        70.0         1.26
# 1   000020     동화약품  KOSPI  20150113     5600.0        40.0         0.71
# 2   000020     동화약품  KOSPI  20150116     5640.0      -110.0        -1.95
# 3   000020     동화약품  KOSPI  20150119     5680.0        40.0         0.70
# 4   000020     동화약품  KOSPI  20150122     5550.0       -60.0        -1.08
#
#    acc_quant  debt_total  face_val  ...  operating_profit  \
# 0    42517.0       732.0      1000  ...             112.0
# 1    39527.0       732.0      1000  ...             112.0
# 2    57341.0       732.0      1000  ...             112.0
# 3    49574.0       732.0      1000  ...             112.0
# 4    77386.0       732.0      1000  ...             112.0
#
#    operating_profit_increasing_rate  prev_quant  property_total  \
# 0                               NaN     62744.0          3706.0
# ...

# %%
# NAVER, SK텔레콤, 삼성전자, 카카오,엔씨소프트, LG전자

# %%
df_item_charge_full.loc[df_item_charge_full.itemname == 'NAVER']
# Out:
#        itemcode itemname market      date  close_val  change_val  change_rate  \
# 272066   035420    NAVER  KOSPI  20150107   732000.0    -11000.0        -1.50
# 272067   035420    NAVER  KOSPI  20150113   740000.0    -10000.0        -1.35
# 272068   035420    NAVER  KOSPI  20150116   777000.0         NaN          NaN
# 272069   035420    NAVER  KOSPI  20150119   776000.0     -1000.0        -0.13
# 272070   035420    NAVER  KOSPI  20150122   765000.0    -15000.0        -1.96
# 272071   035420    NAVER  KOSPI  20150128   777000.0     13000.0         1.67
# 272072   035420    NAVER  KOSPI  20150203   712000.0      1000.0         0.14
# 272073   035420    NAVER  KOSPI  20150206   715000.0      3000.0         0.42
# 272074   035420    NAVER  KOSPI  20150209   681000.0    -34000.0        -4.99
# 272075   035420    NAVER  KOSPI  20150212   680000.0      7000.0         1.03
# 272076   035420    NAVER  KOSPI  20150224   637000.0     -2000.0        -0.31
# ...

# %%
len(df_item_charge_full.loc[df_item_charge_full.itemname == 'NAVER'])
# Out:
# 323

# %%
df_item_charge_full.loc[df_item_charge_full.itemname == 'SK텔레콤']
# Out:
#        itemcode itemname market      date  close_val  change_val  change_rate  \
# 197490    17670    SK텔레콤  KOSPI  20150107   269500.0     -5000.0        -1.86
# 197491    17670    SK텔레콤  KOSPI  20150113   268000.0      1000.0         0.37
# 197492    17670    SK텔레콤  KOSPI  20150116   267500.0     -1000.0        -0.37
# 197493    17670    SK텔레콤  KOSPI  20150119   268000.0       500.0         0.19
# 197494    17670    SK텔레콤  KOSPI  20150122   277000.0      2000.0         0.72
# 197495    17670    SK텔레콤  KOSPI  20150128   285500.0     -2500.0        -0.88
# 197496    17670    SK텔레콤  KOSPI  20150203   282500.0     -5500.0        -1.95
# 197497    17670    SK텔레콤  KOSPI  20150206   278000.0         NaN          NaN
# 197498    17670    SK텔레콤  KOSPI  20150209   277000.0     -1000.0        -0.36
# 197499    17670    SK텔레콤  KOSPI  20150212   289500.0      9000.0         3.11
# 197500    17670    SK텔레콤  KOSPI  20150224   291000.0         NaN          NaN
# ...

# %%
len(df_item_charge_full.loc[df_item_charge_full.itemname == 'SK텔레콤'])
# Out:
# 323

# %%
df_item_charge_full.loc[df_item_charge_full.itemname == '삼성전자']
# Out:
#        itemcode itemname market      date  close_val  change_val  change_rate  \
# 106319   005930     삼성전자  KOSPI  20150107  1307000.0     12000.0         0.92
# 106320   005930     삼성전자  KOSPI  20150113  1339000.0     23000.0         1.72
# 106321   005930     삼성전자  KOSPI  20150116  1316000.0    -18000.0        -1.37
# 106322   005930     삼성전자  KOSPI  20150119  1343000.0     27000.0         2.01
# 106323   005930     삼성전자  KOSPI  20150122  1378000.0    -17000.0        -1.23
# 106324   005930     삼성전자  KOSPI  20150128  1378000.0    -22000.0        -1.60
# 106325   005930     삼성전자  KOSPI  20150203  1366000.0     -2000.0        -0.15
# 106326   005930     삼성전자  KOSPI  20150206  1372000.0     14000.0         1.02
# 106327   005930     삼성전자  KOSPI  20150209  1395000.0     23000.0         1.65
# 106328   005930     삼성전자  KOSPI  20150212  1344000.0    -11000.0        -0.82
# 106329   005930     삼성전자  KOSPI  20150224  1367000.0         NaN          NaN
# ...

# %%
len(df_item_charge_full.loc[df_item_charge_full.itemname == '삼성전자'])
# Out:
# 323

# %%
df_item_charge_full.loc[df_item_charge_full.itemname == '카카오']
# Out:
#        itemcode itemname market      date  close_val  change_val  change_rate  \
# 274327   035720      카카오  KOSPI  20150107   148200.0      2900.0         1.96
# 274328   035720      카카오  KOSPI  20150113   142600.0     -2800.0        -1.96
# 274329   035720      카카오  KOSPI  20150116   153500.0      -900.0        -0.59
# 274330   035720      카카오  KOSPI  20150119   152200.0     -1300.0        -0.85
# 274331   035720      카카오  KOSPI  20150122   147500.0     -5500.0        -3.73
# 274332   035720      카카오  KOSPI  20150128   157400.0      4300.0         2.73
# 274333   035720      카카오  KOSPI  20150203   150000.0      1100.0         0.73
# 274334   035720      카카오  KOSPI  20150206   145700.0     -4100.0        -2.81
# 274335   035720      카카오  KOSPI  20150209   139400.0     -6300.0        -4.52
# 274336   035720      카카오  KOSPI  20150212   145200.0     -2400.0        -1.65
# 274337   035720      카카오  KOSPI  20150224   135700.0       100.0         0.07
# ...

# %%
len(df_item_charge_full.loc[df_item_charge_full.itemname == '카카오'])
# Out:
# 323

# %%
df_item_charge_full.loc[df_item_charge_full.itemname == '엔씨소프트']
# Out:
#        itemcode itemname market      date  close_val  change_val  change_rate  \
# 281433   036570    엔씨소프트  KOSPI  20150107   190000.0     -4000.0        -2.11
# 281434   036570    엔씨소프트  KOSPI  20150113   193500.0     -3000.0        -1.55
# 281435   036570    엔씨소프트  KOSPI  20150116   193000.0      1000.0         0.52
# 281436   036570    엔씨소프트  KOSPI  20150119   189000.0     -4000.0        -2.12
# 281437   036570    엔씨소프트  KOSPI  20150122   181500.0     -4000.0        -2.20
# 281438   036570    엔씨소프트  KOSPI  20150128   217000.0     28000.0        12.90
# 281439   036570    엔씨소프트  KOSPI  20150203   215000.0     14500.0         6.74
# 281440   036570    엔씨소프트  KOSPI  20150206   213000.0      -500.0        -0.23
# 281441   036570    엔씨소프트  KOSPI  20150209   218500.0      5500.0         2.52
# 281442   036570    엔씨소프트  KOSPI  20150212   203000.0     -6500.0        -3.20
# 281443   036570    엔씨소프트  KOSPI  20150224   190500.0       500.0         0.26
# ...

# %%
len(df_item_charge_full.loc[df_item_charge_full.itemname == '엔씨소프트'])
# Out:
# 323

# %%
df_item_charge_full.loc[df_item_charge_full.itemname == 'LG전자']
# Out:
#        itemcode itemname market      date  close_val  change_val  change_rate  \
# 399207    66570     LG전자  KOSPI  20150107    60000.0      -100.0        -0.17
# 399208    66570     LG전자  KOSPI  20150113    61500.0      -600.0        -0.98
# 399209    66570     LG전자  KOSPI  20150116    60800.0      -100.0        -0.16
# 399210    66570     LG전자  KOSPI  20150119    60800.0         NaN          NaN
# 399211    66570     LG전자  KOSPI  20150122    61800.0      1800.0         2.91
# 399212    66570     LG전자  KOSPI  20150128    63500.0      -800.0        -1.26
# 399213    66570     LG전자  KOSPI  20150203    60300.0      -200.0        -0.33
# 399214    66570     LG전자  KOSPI  20150206    60300.0      -300.0        -0.50
# 399215    66570     LG전자  KOSPI  20150209    60100.0      -200.0        -0.33
# 399216    66570     LG전자  KOSPI  20150212    59900.0      -100.0        -0.17
# 399217    66570     LG전자  KOSPI  20150224    61200.0       300.0         0.49
# ...

# %%
df_item_charge_full.market.value_counts()
# Out:
# KOSDAQ    369451
# KOSPI     271377
# KONEX      30190
# Name: market, dtype: int64

# %%
df_item_charge_full.loc[df_item_charge_full.market == 'KONEX']
# Out:
#        itemcode   itemname market      date  close_val  change_val  \
# 320769    44990  에이치엔에스하이텍  KONEX  20151211    15000.0     -2600.0
# 320770    44990  에이치엔에스하이텍  KONEX  20151214    12750.0     -2250.0
# 320771    44990  에이치엔에스하이텍  KONEX  20151217     7870.0     -1380.0
# 320772    44990  에이치엔에스하이텍  KONEX  20151223     7000.0         NaN
# 320773    44990  에이치엔에스하이텍  KONEX  20151229     5250.0      -750.0
# 320774    44990  에이치엔에스하이텍  KONEX  20160106     6000.0       280.0
# 320775    44990  에이치엔에스하이텍  KONEX  20160112     5870.0     -1030.0
# 320776    44990  에이치엔에스하이텍  KONEX  20160115     6500.0       800.0
# 320777    44990  에이치엔에스하이텍  KONEX  20160118     5560.0      -940.0
# 320778    44990  에이치엔에스하이텍  KONEX  20160121     5000.0      -400.0
# 320779    44990  에이치엔에스하이텍  KONEX  20160127     5250.0      -250.0
# 320780    44990  에이치엔에스하이텍  KONEX  20160202     5500.0         NaN
# 320781    44990  에이치엔에스하이텍  KONEX  20160205     5950.0      -600.0
# ...

# %%
df_item_charge_full.loc[df_item_charge_full.market == 'KONEX'].itemname.value_counts()
# Out:
# 에이비온            323
# 엘피케이            323
# 큐엠씨             323
# 옐로페이            323
# 그린플러스           323
# 에스에이티이엔지        323
# 피노텍             323
# 유니포인트           323
# 한중엔시에스          323
# 유비온             323
# 듀켐바이오           323
# 수프로             323
# 태양기계            323
# 비나텍             323
# 이엔드디            323
# 데이터스트림즈         323
# 세종머티리얼즈         323
# 대동고려삼           323
# 아이케이세미콘         323
# 청광종건            323
# 에스엔피제네틱스        323
# 골프존데카           323
# 에프앤가이드          323
# 빅텐츠             323
# 대주이엔티           323
# 툴젠              323
# 위월드             323
# 씨이랩             323
# 에듀파트너           323
# 코셋              323
#                ...
# 두원석재            103
# 탑선               94
# 파인이엠텍            93
# 티에스아이            93
# 미디어젠             91
# 휴럼               85
# 바이오시네틱스          84
# 씨알푸드             84
# TS트릴리온           82
# 라이프사이언스테크놀로지     82
# 위세아이텍            60
# 에스제이켐            54
# 다이노나             53
# 디피코              52
# ...

# %%
df_item_charge_full.loc[df_item_charge_full.itemname == '']
# Out:
# Empty DataFrame
# Columns: [itemcode, itemname, market, date, close_val, change_val, change_rate, acc_quant, debt_total, face_val, frgn_hold_ratio, high_val, listed_stock, low_val, market_sum, net_income, open_val, operating_profit, operating_profit_increasing_rate, prev_quant, property_total, reserve_ratio, roa, roe, sales, sales_increasing_rate, trade_stop_yn]
# Index: []
#
# [0 rows x 27 columns]

# %%
len(df_item_charge_full.loc[df_item_charge_full.itemname == 'LG전자'])
# Out:
# 323

# %%
len(df_foreign_charge)
# Out:
# 8109

# %%
df_foreign_charge.head()
# Out:
#     itemcode      date  close_val  change_val  open_val  high_val   low_val  \
# 0  INI@BSE30  20150101   27507.54        8.12  27485.77  27545.61  27395.34
# 1  INI@BSE30  20150107   26908.82      -78.64  26983.43  27051.60  26776.12
# 2  INI@BSE30  20150113   27425.73     -159.54  27611.56  27670.19  27324.58
# 3  INI@BSE30  20150116   28121.89       46.34  28056.61  28176.10  27945.31
# 4  INI@BSE30  20150119   28262.01      140.12  28249.84  28334.06  28197.36
#
#     itemname country_name
# 0  인도 SENSEX           인도
# 1  인도 SENSEX           인도
# 2  인도 SENSEX           인도
# 3  인도 SENSEX           인도
# 4  인도 SENSEX           인도

# %%
df_foreign_charge.country_name.value_counts()
# Out:
# 미국       1979
# 홍콩        956
# 중국        951
# 독일        661
# 프랑스       331
# 이탈리아      330
# 러시아       328
# 영국        326
# 베트남       324
# 브라질       323
# 대만        322
# 인도네시아     321
# 인도        320
# 말레이시아     319
# 일본        318
# Name: country_name, dtype: int64

# %%
df_foreign_charge.itemcode.value_counts()
# Out:
# STX@SX5E       332
# PAS@CAC40      331
# NAS@NDX        330
# ITI@FTSEMIB    330
# DJI@DJI        330
# NAS@IXIC       330
# DJI@DJT        330
# SPI@SPX        330
# NAS@SOX        329
# XTR@DAX30      329
# RUI@RTSI       328
# LNS@FTSE100    326
# HAS@HNX        324
# BRI@BVSP       323
# TWS@TI01       322
# IDI@JKSE       321
# INI@BSE30      320
# HSI@HSCC       319
# MYI@KLSE       319
# HSI@HSCE       319
# NII@NI225      318
# HSI@HSI        318
# SHS@000003     317
# SHS@000001     317
# SHS@000002     317
# Name: itemcode, dtype: int64

# %%
df_foreign_charge.loc[df_foreign_charge.country_name == '미국'].itemname.value_counts()
# Out:
# S&P 500      330
# 다우 운송        330
# 나스닥 100      330
# 다우 산업        330
# 나스닥 종합       330
# 필라델피아 반도체    329
# Name: itemname, dtype: int64

# %%
df_kr_index.head()
# Out:
#   itemcode      date  close_val  change_val  change_rate  acc_quant  \
# 0   KOSDAQ  20150107      56132       242.0         0.43     488995
# 1   KOSDAQ  20150113      57100      -376.0        -0.65     544245
# 2   KOSDAQ  20150116      57741      -398.0        -0.68     422973
# 3   KOSDAQ  20150119      57794        53.0         0.09     434141
# 4   KOSDAQ  20150122      57842      -592.0        -1.01     639503
#
#    acc_amount
# 0     3011838
# 1     2771338
# 2     2699868
# 3     2478185
# 4     3251362

# %%
df_item_charge_full.loc[df_item_charge_full.itemname == '하이트진로'].acc_quant.value_counts()
# Out:
# 137471.0     1
# 545407.0     1
# 547724.0     1
# 289616.0     1
# 253206.0     1
# 180521.0     1
# 150785.0     1
# 116803.0     1
# 94037.0      1
# 467541.0     1
# 121043.0     1
# 193323.0     1
# 322391.0     1
# 99646.0      1
# 86422.0      1
# 195732.0     1
# 146839.0     1
# 164911.0     1
# 245165.0     1
# 1715511.0    1
# 430924.0     1
# 142526.0     1
# 254623.0     1
# 246649.0     1
# 366657.0     1
# 254934.0     1
# 256033.0     1
# 447043.0     1
# 211351.0     1
# 231074.0     1
#             ..
# 467637.0     1
# 187256.0     1
# 193588.0     1
# 236379.0     1
# 166922.0     1
# 357047.0     1
# 205792.0     1
# 233497.0     1
# 143325.0     1
# 192781.0     1
# 107819.0     1
# 164429.0     1
# 165476.0     1
# 327248.0     1
# 164046.0     1
# 382365.0     1
# 356766.0     1
# 283295.0     1
# 133788.0     1
# 215531.0     1
# 230993.0     1
# 218965.0     1
# 178898.0     1
# 198665.0     1
# 489382.0     1
# 424880.0     1
# 94587.0      1
# ...

# %%
df_item_charge_full.loc[(df_item_charge_full.itemname == '하이트진로') & (df_item_charge_full.date > 20180000)].net_income.value_counts()
# Out:
# 223.0    80
# Name: net_income, dtype: int64
